# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
variants = [1,2,4,8]
G_0 = 1000

gp_start = 80
x_values = np.linspace(0,G_0,10)
rates = [
[
    [
        j * gp_start * (1 - gp/G_0)
    for gp in x_values]]
for j in variants]


from typing import List, Tuple, Dict
class ProxyModel:
    _req:Dict[str,'ProxyModel']={}
    def __init__(self,name:str, fgpt:List[float], *all_fgpr:List[float] ) -> None:
        self.fgpt = np.array(fgpt)
        self.all_fgpr = [
            np.array(x).reshape((10,))
        for x in all_fgpr]
        self.all_dq =  [
            self.all_fgpr[ind+1] - self.all_fgpr[0]    
        for ind in range(len(self.all_fgpr)-1)]
        self._req = [name,self]
    def show(self):
        fig, axes = plt.subplots(ncols=2,nrows=1)
        ax = axes[0]
        for fgpr in self.all_fgpr:
            ax.plot(self.fgpt,fgpr)
        ax.set_xlim(0)
        ax.set_ylim(0)
        ax2 = axes[1]

        for dq in self.all_dq:
            ax2.plot(self.fgpt, dq)
        # plt.show()
    def hvs(x:float, x0:float)->float:return 0 if x < x0 else 1
    def 
    def prox(self, gp1:float, gp2:float, gp3:float)->float:
        return     
        

p = ProxyModel('sad', x_values, *rates)    
p.show()
